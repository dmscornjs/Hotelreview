# %% [markdown]
# <a href="https://colab.research.google.com/github/dmscornjs/Hotelreview/blob/main/%ED%86%A0%ED%94%BD%EB%AA%A8%EB%8D%B8%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install contextualized-topic-models==2.2.0

# %%
# %%capture
# !pip install pyldavis

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 13.69 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4 MB 994 kB/s
# ...
#      |████████████████████████████████| 448 kB 62.1 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-05-11 16:01:05--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c0:3470, 2406:da00:ff00::22e9:9f55, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# ...

# %% [markdown]
# ```
# !pip install git+https://github.com/ssut/py-hanspell.git
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# !pip install konlpy
# !pip install wordcloud
# !pip install gensim
# ```
#
#
# *   클러스터링

# %% [markdown]
# 코랩 런타임 끊기지 않고 하는 법
#
#
# function ClickConnect(){ console.log("Working"); document.querySelector("colab-toolbar-button").click() }setInterval(ClickConnect, 1800000)

# %%
# !pip install konlpy
# !pip install gensim
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 6.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 55.5 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import sys
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv("/content/drive/MyDrive/합친데이터명사포함.csv")
top = pd.read_csv("/content/drive/MyDrive/야놀자명사100.csv",encoding='utf-8',delimiter="\t",header = None )

# %%
top = top[:100]

# %%
top.columns=["n", "c", "t"]

# %%
top.t.value_counts()
# Out:
# 0    36
# 1    30
# 2    13
# 5    11
# 3     7
# 4     3
# Name: t, dtype: int64

# %%
n1 = list(top.n.loc[top.t==1])
n2 = list(top.n.loc[top.t==2])
n3 = list(top.n.loc[top.t==3])
n4 = list(top.n.loc[top.t==4])

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df['시설']=0
df['서비스']=0
df['위치']=0
df['가격']=0

# %%
df
# Out:
#              hotel  star                                             review  \
# 0         신라스테이 역삼     4  출장으로 역삼 근처 호텔 찾아보다가 신라스테이 근처에 센터필드도 있고 밥집 카페도 ...
# 1         신라스테이 역삼     5  잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬잘쉬디으잘쉬디으...
# 2         신라스테이 역삼     5  깔끔하고 고급스러웠습니다 가격대비 만족했던곳이라 넘넘 만족스러웠어요 로비도 깔끔하고...
# 3         신라스테이 역삼     5  직원분들 너무 친절하십니다 안내데스크가 넓어서 잠시 쉬기에도 편합니다 편의점이 바로...
# 4         신라스테이 역삼     5  깔끔하고 서울에서 갑자기 일이 있거나 놀게 되었을 때 가장 합리적인 선택이라고 생각합니다
# ...            ...   ...                                                ...
# 200909   파크 하비오 호텔     5                              덕분에 편안하고 좋은 여행이 되었습니다
# 200910  그랜드 하얏트 서울     5                           24개월 아가침대방으로 너무편하게잘쉬고왔어요
# 200911  그랜드 하얏트 서울     4                    친절하시고 조식도 맛있었어요하지만 방음이많이 안되더라구요
# 200912  그랜드 하얏트 서울     5  역시 5성급 하얏트답습니다 조식 포함시 좀 비싸긴 한데 조식빼고 생각하면 매우 괜찮...
# 200913  그랜드 하얏트 서울     5                                           완전 좋았습니디
#
#                 date     real_date  length  \
# ...

# %%
for x in n1:
  df['시설'][df.review_spell_check.str.contains(x)]+=1
for x in n2:
  df['서비스'][df.review_spell_check.str.contains(x)]+=1
for x in n3:
  df['위치'][df.review_spell_check.str.contains(x)]+=1
for x in n4:
  df['가격'][df.review_spell_check.str.contains(x)]+=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# ...

# %%
df_new = df.loc[:,['시설', '서비스', '위치', '가격']].max(axis=1)

# %%
df['label'] = 0

# %%
df.label.loc[df['시설']==df_new]=1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.label.loc[df['서비스']==df_new]=2
df.label.loc[df['위치']==df_new]=3
df.label.loc[df['가격']==df_new]=4

# %%
df.label.loc[df_new==0]=0

# %%
df.drop('sum', axis=1)
# Out:
#              hotel  star                                             review  \
# 0         신라스테이 역삼     4  출장으로 역삼 근처 호텔 찾아보다가 신라스테이 근처에 센터필드도 있고 밥집 카페도 ...
# 1         신라스테이 역삼     5  잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬디으잘쉬잘쉬디으잘쉬디으...
# 2         신라스테이 역삼     5  깔끔하고 고급스러웠습니다 가격대비 만족했던곳이라 넘넘 만족스러웠어요 로비도 깔끔하고...
# 3         신라스테이 역삼     5  직원분들 너무 친절하십니다 안내데스크가 넓어서 잠시 쉬기에도 편합니다 편의점이 바로...
# 4         신라스테이 역삼     5  깔끔하고 서울에서 갑자기 일이 있거나 놀게 되었을 때 가장 합리적인 선택이라고 생각합니다
# ...            ...   ...                                                ...
# 200909   파크 하비오 호텔     5                              덕분에 편안하고 좋은 여행이 되었습니다
# 200910  그랜드 하얏트 서울     5                           24개월 아가침대방으로 너무편하게잘쉬고왔어요
# 200911  그랜드 하얏트 서울     4                    친절하시고 조식도 맛있었어요하지만 방음이많이 안되더라구요
# 200912  그랜드 하얏트 서울     5  역시 5성급 하얏트답습니다 조식 포함시 좀 비싸긴 한데 조식빼고 생각하면 매우 괜찮...
# 200913  그랜드 하얏트 서울     5                                           완전 좋았습니디
#
#                 date     real_date  length  \
# ...

# %%
df.label.value_counts()
# Out:
# 1    78828
# 2    48811
# 0    47374
# 3    15590
# 4    10311
# Name: label, dtype: int64

# %% [markdown]
# # 토픽모델링

# %% [markdown]
# 설치 후 재시작 필요

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation, bert_embeddings_from_list
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from tqdm import tqdm

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
train_bow_embeddings = vectorizer.fit_transform(df.review_spell_check)

# %%
print(train_bow_embeddings.shape)
# Out:
# (200914, 3000)

# %%
vocab = vectorizer.get_feature_names()
id2token = {k: v for k, v in zip(range(0, len(vocab)), vocab)}
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
train_contextualized_embeddings = bert_embeddings_from_list(df.review_spell_check, \
                                                            "sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens")
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1005 [00:00<?, ?it/s]

# %%
qt = TopicModelDataPreparation()

training_dataset = qt.load(train_contextualized_embeddings, train_bow_embeddings, id2token)

# %%
ctm = CombinedTM(bow_size=len(vocab), contextual_size=768, n_components=30, num_epochs=20)
ctm.fit(training_dataset)
# Out:
# Epoch: [20/20]	 Seen Samples: [4018280/4018280]	Train Loss: 113.08364592537689	Time: 0:00:57.870195: : 20it [19:48, 59.41s/it]

# %%
ctm.get_topics(5)
# Out:
# defaultdict(list,
#             {0: ['조용', '아늑', '푹신', '깔끔', '침구'],
#              1: ['교통', '가깝', '접근성', '가까워', '가까워서'],
#              2: ['편히', '머물', '지내', '갑니다', '가요'],
#              3: ['는데', '어요', '조식', '어서', '이용'],
#              4: ['어요', '는데', '침대', '너무', '해서'],
#              5: ['셔서', '습니다', '조식', '는데', '방문'],
#              6: ['오히려', '머신', '지상', '아도', '자분'],
#              7: ['방문', '이용', '감사', '입니다', '친절'],
#              8: ['대로변', '취사', '오피스텔', '쇼핑몰', '매우'],
#              9: ['항상', '매번', '신라', '마다', '스테이'],
#              10: ['어서', '어요', '아서', '는데', '바로'],
#              11: ['습니다', '으로', '어서', '지만', '이용'],
#              12: ['어서', '어요', '습니다', '해서', '깔끔'],
#              13: ['맛있', '조식', '너무', '예쁘', '다음'],
#              14: ['대비', '서비스', '모두', '가격', '스러웠'],
#              15: ['시간', '주차', '체크인', '네요', '체크'],
#              16: ['오히려', '지상', '아도', '만약', '착용'],
#              17: ['호텔', '에서', '지만', '으로', '생각'],
#              18: ['아주', '아요', '착용', '놓여', '마주치'],
# ...

# %%
#30개 토픽 시각화
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(vocab, training_dataset, n_samples=10)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# Sampling: [10/10]: : 10it [08:12, 49.30s/it]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el105391405149824438565319911640"></div>
# <script type="text/javascript">
#
# ...

# %%
#4개 토픽 시각화
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(vocab, training_dataset, n_samples=10)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# Sampling: [10/10]: : 10it [08:20, 50.09s/it]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el10539140514982443344916550693"></div>
# <script type="text/javascript">
#
# ...

# %%
#10개 토픽 시각화 
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(vocab, training_dataset, n_samples=10)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping
# Sampling: [10/10]: : 10it [08:15, 49.59s/it]
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# ...
